# %% [markdown]
# # __AD470 Data Science Practicum__
#
# ## __Team Members__
# - Mona Mohamed
# - Peter Torres
# - Chris Navoczynski
#
# ## __Team GitHub Repo Link:__
# https://github.com/ChrisNavoczynski/AD470-Team-MPC-SP2022
# <br>(Invite sent to instructor to be a collaborator)
#
#
# ## __Team Project/Task Management Board:__
# https://github.com/ChrisNavoczynski/AD470-Team-MPC-SP2022/projects/1
#
#
# ## __Google Drive Repo:__
#
# https://colab.research.google.com/drive/115kvkoemulnInZwjHwlTsJUkIwzFMNyj?usp=sharing
# <br>(Invite sent to instructor to be a collaborator)
#
# ## __Group Communication:__
# Group communication will happen on Slack:
# We have one donated to progress and questions that include our instructor.
# - ad470-group1-questions
#
# We have seperated group one for helping each other out and plan meetings.
#
# Emails:
# - monaatabani@gmail.com
# - torres7p@gmail.com
# - chrisnavo01@gmail.com
